# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.upload()   # a file picker opens; select nexus.zip from your Mac
# Out:
#      <input type="file" id="files-2a4c64ea-ebac-420b-a32e-b860c1850f41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a4c64ea-ebac-420b-a32e-b860c1850f41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q nexus.zip
# %cd nexus
# !pip -q install -r requirements.txt
# Out:
# /content/nexus

# %%
# %cd /content
# !rm -rf nexus
# !unzip -q nexus.zip -d /content
# %cd /content/nexus
# !ls
# Out:
# /content

# %%
# !pip -q install -r requirements.txt
# !python claim1_cross_model_probe.py
# !python claim2_codec_properties.py
# Out:
# === gpt2 ===
# ...
# config.json: 100% 665/665 [00:00<00:00, 3.75MB/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 109kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 21.1MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 18.7MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 9.66MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# model.safetensors: downloading bytes:  28% 153M/548M [00:01<00:01, 206MB/s, 12.1MB/s  ]
# model.safetensors: downloading bytes:  52% 287M/548M [00:02<00:01, 173MB/s, 25.0MB/s  ]
# model.safetensors: reconstructing file:  37% 201M/548M [00:02<00:03, 107MB/s, 6.46MB/s  ]
# model.safetensors: downloading bytes:  86% 470M/548M [00:02<00:00, 259MB/s, 38.6MB/s  ]
# model.safetensors: reconstructing file:  73% 402M/548M [00:02<00:00, 168MB/s, 24.9MB/s  ]
# model.safetensors: downloading bytes: 100% 474M/474M [00:03<00:00, 148MB/s, 41.0MB/s  ]
# ...

# %%
# !ls -R results
# !zip -rq claim12_results.zip results
from google.colab import files
files.download("claim12_results.zip")
# Out:
# results:
# claim1	claim2
#
# results/claim1:
# anisotropy_table.csv  loose_morph_table.csv
# loose_morph_bar.png   qualitative_neighbors.json
#
# results/claim2:
# checks.json		dp_coverage.csv  neighbors.json
# codec_cosine_table.csv	jaccard.csv
